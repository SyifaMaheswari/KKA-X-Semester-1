# %% [markdown]
# <a href="https://colab.research.google.com/github/SyifaMaheswari/KKA-X-Semester-1/blob/main/Tiga_aplikasi_sederhana_kalkulator_Syifa_Titania_X6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
jari_jari = int(input("masukkan jari jari dari tabung dengan panjang (cm) : "))
tinggi = int(input("masukkan tinggi dari tabung dengan panjang (cm) : "))

volume = 22/7 * 7 * 7 * 20

print(f"\nvolume dari tabung tersebut yaitu {volume} cm^3")
# Out:
# masukkan jari jari dari tabung dengan panjang (cm) : 7
# masukkan tinggi dari tabung dengan panjang (cm) : 20
#
# volume dari tabung tersebut yaitu 3080.0 cm^3

# %%
panjang = int(input("masukkan panjang dari persegi panjang (cm) : "))
lebar = int(input("masukkan lebar dari persegi panjang (cm "))

luas = panjang * lebar

print(f"\nluas dari persegi panjang yaitu {luas} cm")
# Out:
# masukkan panjang dari persegi panjang (cm) : 5
# masukkan lebar dari persegi panjang (cm 4
#
# luas dari persegi panjang yaitu 20 cm
