# %% [markdown]
# <a href="https://colab.research.google.com/github/SyifaMaheswari/KKA-X-Semester-1/blob/main/fungsi_print_Tania_X_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# menampilkan teks bebas

# %%
print("tania imut")
# Out:
# tania imut

# %%
print("""
nama : Syifa Titania Maheswari
kelas : X.6
""")
# Out:
# nama : Syifa Titania Maheswari
# kelas : X.6

# %% [markdown]
# menampilkan nilai variabel

# %%
nama = "Syifa Titania Maheswari"
usia = 14

print(nama)
print(usia)
# Out:
# Syifa Titania Maheswari
# 14

# %%
warna_favorit = "ungu"
berat_badan = 60

print(warna_favorit)
print(berat_badan)
# Out:
# ungu
# 60

# %%
nama : "Syifa Titania Maheswari"

print("Syifa Titania Maheswari")
# Out:
# Syifa Titania Maheswari

# %% [markdown]
# menampilkan teks bebas dan nilai variabel

# %%
nama = "Syifa Titania Maheswari"
beratbadan = 60

print("nama: "+ nama)
# Out:
# nama: Syifa Titania Maheswari

# %%
print("beratbadan: "+ str(beratbadan))
# Out:
# beratbadan: 60

# %%
print("nama:", nama , "loh")
# Out:
# nama: Syifa Titania Maheswari loh

# %%
print("berat badan:" , beratbadan)
# Out:
# berat badan: 60

# %%
print(f"nama: {nama} loh")
# Out:
# nama: Syifa Titania Maheswari loh

# %% [markdown]
# Escape Character

# %%
print("""Nama: Syifa Titania Maheswari
kelas: X.6
No. Absen : 37""")
# Out:
# Nama: Syifa Titania Maheswari
# kelas: X.6
# No. Absen : 37

# %%
print("Nama: Syifa Titania Maheswari")
print("kelas: X.6")
print("No. Absen: 37")
# Out:
# Nama: Syifa Titania Maheswari
# kelas: X.6
# No. Absen: 37

# %%
print("Nama: Syifa Titania Maheswari\nKelas: X.6\nNo. Absen: 37")
# Out:
# Nama: Syifa Titania Maheswari
# Kelas: X.6
# No. Absen: 37

# %%
print("nama\t\t: Syifa Titania Maheswari\nKelas\t\t: X.6\nNo. Absen\t: 37")
# Out:
# nama		: Syifa Titania Maheswari
# Kelas		: X.6
# No. Absen	: 37

# %%
print('nama\t\t: Syifa Titania Maheswari\nKelas\t\t: X.6\nNo. Absen\t: 37')
# Out:
# nama		: Syifa Titania Maheswari
# Kelas		: X.6
# No. Absen	: 37

# %%
print("nama\t\t: Ja'far Shodiq\nKelas\t\t: X.6\nNo. Absen\t: 37")
# Out:
# nama		: Ja'far Shodiq
# Kelas		: X.6
# No. Absen	: 37

# %%
print("lokasi file tugas KKA: C:\\KKA\\Tugas Shinta")
# Out:
# lokasi file tugas KKA: C:\KKA\Tugas Shinta

# %%
print("Bu Shinta berkata, \"tolong perhatikan ke layar tv!\".")
# Out:
# Bu Shinta berkata, "tolong perhatikan ke layar tv!".

# %%
print ('Bu Shinta berkata, "Tolong perhatikan ke layar tv!".')
# Out:
# Bu Shinta berkata, "Tolong perhatikan ke layar tv!".

# %% [markdown]
# Parameter fungsi print

# %%
tahun=2010
bulan= "November"
tanggal=29

print(tahun, end="-")
print(bulan, end="-")
print(tanggal)
# Out:
# 2010-November-29

# %%
print(tahun, end="/")
print(bulan, end="/")
print(tanggal)
# Out:
# 2010/November/29

# %%
nama_siswa_1 = "fida"
nama_siswa_2 = "aji"
nama_siswa_3 = "hadziq"

print(nama_siswa_1, end="~")
print(nama_siswa_2, end="~")
print(nama_siswa_3)
# Out:
# fida~aji~hadziq

# %%
print(nama_siswa_1, nama_siswa_2, nama_siswa_3, sep="_")
# Out:
# fida_aji_hadziq

# %%
print(nama_siswa_2, nama_siswa_1, nama_siswa_3, nama_siswa_2, sep="~")
# Out:
# aji~fida~hadziq~aji
