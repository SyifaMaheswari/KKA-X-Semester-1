# %% [markdown]
# <a href="https://colab.research.google.com/github/SyifaMaheswari/KKA-X-Semester-1/blob/main/Tipe_Variabel_Syifa_T_M.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Syifa Titania Maheswari
#
# Kelas : X.6
#
# No. Absen : 37

# %% [markdown]
# #konsep dasar variabel

# %%
print("syifatitania.2025@gmail.com")
print("syifatitania.2025@gmail.com")
print("syifatitania.2025@gmail.com")
print("syifatitania.2025@gmail.com")
# Out:
# syifatitania.2025@gmail.com
# syifatitania.2025@gmail.com
# syifatitania.2025@gmail.com
# syifatitania.2025@gmail.com

# %%
email_user_1 = "syifatitania.2025@gmail.com"

print(email_user_1)
print(email_user_1)
print(email_user_1)
print(email_user_1)
# Out:
# syifatitania.2025@gmail.com
# syifatitania.2025@gmail.com
# syifatitania.2025@gmail.com
# syifatitania.2025@gmail.com

# %% [markdown]
# peraturan penulisan variabel

# %%
#penulisan variabel hanya boleh angka, huruf, underscore
#emailuser1 = "syifatitania.2025@gmail.com

emailuser1 = "syifatitania.2025@gmail.com"
print(emailuser1)
# Out:
# syifatitania.2025@gmail.com

# %%
#penulisan variabel tidak boleh diawali dengan angka
1_email_user = syifatitania.2025@gmail.com
print = (1_email_user
# Out:
#   File "/tmp/ipython-input-3536336723.py", line 2
#     1_email_user = syifatitania.2025@gmail.com
#      ^
# SyntaxError: invalid decimal literal

# %%
#penulisan variabel itu sensitif
nama_siswa_1 = "syifa titania maheswari"
print(Nama_siswa_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2229765778.py in <cell line: 0>()
#       1 #penulisan variabel itu sensitif
#       2 nama_siswa_1 = "syifa titania maheswari"
# ----> 3 print(Nama_siswa_1)
#
# NameError: name 'Nama_siswa_1' is not defined
